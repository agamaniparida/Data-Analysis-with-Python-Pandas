# %%
1+1
# Out:
# 2

# %%
import pandas as pd
import numpy as np
s={'Name':['x','y','z'],'Age':[1,2,3],'Rating':[6,7,8]}
data=pd.DataFrame(s)
data1=data.pop('Age')
data['Age']=[1,2,3]
data=data.drop(0)
print(data)
# Out:
#   Name  Rating  Age
# 1    y       7    2
# 2    z       8    3

# %%
from sklearn import linear_model
>>> reg = linear_model.LinearRegression()
>>> reg.fit ([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
>>> reg.coef_
array([ 0.5,  0.5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9896a9d385db> in <module>()
#       2 reg = linear_model.LinearRegression()
#       3 reg.fit ([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
# ----> 4 LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
#       5 reg.coef_
#       6 array([ 0.5,  0.5])
#
# NameError: name 'LinearRegression' is not defined

# %%
def f(x,l=[]):
    for i in range(x):
        print(i)
        l.append(i*i)
    print(l) 

f(2)
f(3,[3,2,1])
f(3)
# Out:
# 0
# 1
# [0, 1]
# 0
# 1
# 2
# [3, 2, 1, 0, 1, 4]
# 0
# 1
# 2
# [0, 1, 0, 1, 4]

# %%
import numpy as np 
from matplotlib import pyplot as plt 

x = np.arange(1,11) 
y = 2 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.bar(x,y) 
plt.show()

# %%
import pandas as pd
price=[1,2,1.2,2]
fruit=['apple','orange','mango','apple']
pd.Series(fruit,price)
pd.Series
# Out:
# 1.0     apple
# 2.0    orange
# 1.2     mango
# 2.0     apple
# dtype: object

# %%
import pandas as pd
nba=pd.read_csv("nba.csv")
nba[["Name","Team","Salary"]].tail()
#nba["Sport"]="Basketbal"
# Out:
#              Name       Team     Salary
# 453  Shelvin Mack  Utah Jazz  2433333.0
# 454     Raul Neto  Utah Jazz   900000.0
# 455  Tibor Pleiss  Utah Jazz  2900000.0
# 456   Jeff Withey  Utah Jazz   947276.0
# 457           NaN        NaN        NaN

# %%
nba['College'].fillna('No College')
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4             No College
# 5             No College
# 6                    LSU
# 7                Gonzaga
# 8             Louisville
# 9         Oklahoma State
# 10            Ohio State
# 11            Washington
# 12            Ohio State
# 13              Kentucky
# 14        North Carolina
# 15            No College
# 16        Oklahoma State
# 17        North Carolina
# 18               Arizona
# 19          Georgia Tech
# 20            No College
# 21            Cincinnati
# 22            Miami (FL)
# 23              Stanford
# 24              Syracuse
# 25           Saint Louis
# 26                Kansas
# 27            Georgetown
# 28             Texas A&M
# 29          Georgia Tech
#              ...
# 428          Wake Forest
# 429           Notre Dame
# 430           California
# 431       North Carolina
# 432           St. John's
# 433                 Duke
# ...

# %%
nba.sort_values(["Team","Name"],ascending=[False,True])
# Out:
#                  Name                Team  Number Position   Age Height  \
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0    6-6
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0    6-5
# 372       Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10
# 380    Garrett Temple  Washington Wizards    17.0       SG  30.0    6-6
# 374        JJ Hickson  Washington Wizards    21.0        C  27.0    6-9
# 370      Jared Dudley  Washington Wizards     1.0       SF  30.0    6-7
# 371      Jarell Eddie  Washington Wizards     8.0       SG  24.0    6-7
# 382         John Wall  Washington Wizards     2.0       PG  25.0    6-4
# 377   Kelly Oubre Jr.  Washington Wizards    12.0       SF  20.0    6-7
# 373     Marcin Gortat  Washington Wizards    13.0        C  32.0   6-11
# 381   Marcus Thornton  Washington Wizards    15.0       SF  29.0    6-4
# 376   Markieff Morris  Washington Wizards     5.0       PF  26.0   6-10
# ...

# %%
nba["Salary"]=nba["Salary"].fillna(0).astype("int")
nba["Salary Rank"]=nba["Salary"].rank(ascending=False).astype("int")
nba.sort_values("Salary Rank")
# Out:
#                        Name                    Team  Number Position   Age  \
# 109             Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0
# 169            LeBron James     Cleveland Cavaliers    23.0       SF  31.0
# 33          Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 251           Dwight Howard         Houston Rockets    12.0        C  30.0
# 339              Chris Bosh              Miami Heat     1.0       PF  32.0
# 100              Chris Paul    Los Angeles Clippers     3.0       PG  31.0
# 414            Kevin Durant   Oklahoma City Thunder    35.0       SF  27.0
# 164            Derrick Rose           Chicago Bulls     1.0       PG  27.0
# 349             Dwyane Wade              Miami Heat     3.0       SG  34.0
# 294       LaMarcus Aldridge       San Antonio Spurs    12.0       PF  30.0
# 23              Brook Lopez           Brooklyn Nets    11.0        C  28.0
# ...

# %%
import pandas as pd
sales=pd.read_csv("salesmen.csv",parse_dates=["Date"])
sales.head(3)
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
sales.pivot(index="Salesman",columns="Date")
# Out:
#             Revenue                                                         \
# Date     2016-01-01 2016-01-02 2016-01-03 2016-01-04 2016-01-05 2016-01-06
# Salesman
# Bob            7172       6362       5982       7917       7837       1744
# Dave           1864       8278       4226       3868       2287       7859
# Jeb            4430       8026       5188       3144        938       8702
# Oscar          5250       8661       7075       2524       2793       7794
# Ronald         2639       4951       2703       4258       7771       5930
#
#                                                         ...                 \
# Date     2016-01-07 2016-01-08 2016-01-09 2016-01-10    ...     2016-12-22
# Salesman                                                ...
# Bob             918       9863       8337       7543    ...           5294
# Dave           8597       3092       1794       7105    ...           6986
# ...

# %%
sales.pivot_table(values="Revenue",index="Salesman")
# Out:
#               Revenue
# Salesman
# Bob       4992.292350
# Dave      5079.407104
# Jeb       5241.579235
# Oscar     4857.319672
# Ronald    4992.109290

# %%
sales.query("Salesman=='Bob'")
# Out:
#           Date Salesman  Revenue
# 0   2016-01-01      Bob     7172
# 1   2016-01-02      Bob     6362
# 2   2016-01-03      Bob     5982
# 3   2016-01-04      Bob     7917
# 4   2016-01-05      Bob     7837
# 5   2016-01-06      Bob     1744
# 6   2016-01-07      Bob      918
# 7   2016-01-08      Bob     9863
# 8   2016-01-09      Bob     8337
# 9   2016-01-10      Bob     7543
# 10  2016-01-11      Bob     1053
# 11  2016-01-12      Bob     4362
# 12  2016-01-13      Bob     6812
# 13  2016-01-14      Bob     9047
# 14  2016-01-15      Bob     3594
# 15  2016-01-16      Bob     9800
# 16  2016-01-17      Bob     7215
# 17  2016-01-18      Bob     7744
# 18  2016-01-19      Bob     9560
# 19  2016-01-20      Bob     9863
# 20  2016-01-21      Bob      547
# 21  2016-01-22      Bob     3505
# 22  2016-01-23      Bob     6969
# 23  2016-01-24      Bob      696
# 24  2016-01-25      Bob     4302
# 25  2016-01-26      Bob     9427
# 26  2016-01-27      Bob     7990
# ...
