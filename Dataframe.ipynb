# %%
import pandas as pd
df=pd.read_csv("employees.csv",parse_dates=["Start Date","Last Login Time"])
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2017-08-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2017-08-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2017-08-10 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2017-08-10 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2017-08-10 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
pd.to_datetime(df["Strat Date"])
pd.to_datetime(df["Last Login Time"])
# Out:
# 0     2017-08-09 12:42:00
# 1     2017-08-09 06:53:00
# 2     2017-08-09 11:17:00
# 3     2017-08-09 13:00:00
# 4     2017-08-09 16:47:00
# 5     2017-08-09 01:35:00
# 6     2017-08-09 16:20:00
# 7     2017-08-09 10:43:00
# 8     2017-08-09 06:29:00
# 9     2017-08-09 06:51:00
# 10    2017-08-09 09:01:00
# 11    2017-08-09 15:19:00
# 12    2017-08-09 01:08:00
# 13    2017-08-09 23:40:00
# 14    2017-08-09 07:13:00
# 15    2017-08-09 06:09:00
# 16    2017-08-09 05:56:00
# 17    2017-08-09 19:45:00
# 18    2017-08-09 10:27:00
# 19    2017-08-09 03:48:00
# 20    2017-08-09 19:18:00
# 21    2017-08-09 02:12:00
# 22    2017-08-09 01:58:00
# 23    2017-08-09 16:19:00
# 24    2017-08-09 22:08:00
# 25    2017-08-09 01:12:00
# 26    2017-08-09 07:45:00
# 27    2017-08-09 18:58:00
# 28    2017-08-09 18:30:00
# 29    2017-08-09 22:06:00
#               ...
# 970   2017-08-09 20:54:00
# 971   2017-08-09 02:01:00
# 972   2017-08-09 14:49:00
# 973   2017-08-09 23:08:00
# 974   2017-08-09 18:31:00
# ...

# %%
df[df["Team"]=="Finance"]
df[df["Team"]!="Finance"]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
mask1=df["Team"].isnull()
df[mask1]
mask2=df["Senior Management"].notnull()
df[mask2]
#mask3=df["Team"].isin(["Legal","Finance"])
#df[mask3]
#df[df.notnull()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2017-08-10 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2017-08-10 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2017-08-10 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2017-08-10 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2017-08-10 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2017-08-10 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2017-08-10 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2017-08-10 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2017-08-10 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2017-08-10 06:51:00  139852    7.524
# 10      Louise  Female 1980-08-12 2017-08-10 09:01:00   63241   15.132
# 11       Julie  Female 1997-10-26 2017-08-10 15:19:00  102508   12.637
# ...

# %%
df.sort_values("First Name",inplace=True)
mask4=~df.duplicated(subset=["First Name"],keep=False)
df[mask4]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2017-08-09 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2017-08-09 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2017-08-09 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2017-08-09 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2017-08-09 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2017-08-09 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2017-08-09 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2017-08-09 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2017-08-09 10:30:00  132839   17.463
#
#     Senior Management                  Team
# 8                True           Engineering
# 688              True                 Legal
# 190             False               Finance
# 887             False                 Legal
# ...

# %%
df["Team"]=df["Team"].fillna("No Dept")
df["Team"].unique()
# Out:
# array(['Marketing', 'Client Services', 'Distribution', 'Product',
#        'Human Resources', 'Engineering', 'Finance', 'Business Development',
#        'Sales', 'No Dept', 'Legal'], dtype=object)

# %%
bond=pd.read_csv("jamesbond.csv")
bond.set_index("Film",inplace=True)
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.reset_index(inplace=True)
bond.set_index("Year",inplace=True)
bond.head()
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
# 1965            Thunderball  Sean Connery  Terence Young       848.1    41.9
# 1967          Casino Royale   David Niven     Ken Hughes       315.0    85.0
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2
# 1965                4.7
# 1967                NaN

# %%
bond.loc[1962]
# Out:
# Film                        Dr. No
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   448.8
# Budget                           7
# Bond Actor Salary              0.6
# Name: 1962, dtype: object

# %%
mask=bond["Actor"]=="Sean Connery"
bond.loc[mask,"Actor"]="Sir Sean Connery"
bond
# Out:
#                                  Film             Actor            Director  \
# Year
# 1962                           Dr. No  Sir Sean Connery       Terence Young
# 1963            From Russia with Love  Sir Sean Connery       Terence Young
# 1964                       Goldfinger  Sir Sean Connery        Guy Hamilton
# 1965                      Thunderball  Sir Sean Connery       Terence Young
# 1967                    Casino Royale       David Niven          Ken Hughes
# 1967              You Only Live Twice  Sir Sean Connery       Lewis Gilbert
# 1969  On Her Majesty's Secret Service    George Lazenby       Peter R. Hunt
# 1971             Diamonds Are Forever  Sir Sean Connery        Guy Hamilton
# 1973                 Live and Let Die       Roger Moore        Guy Hamilton
# 1974      The Man with the Golden Gun       Roger Moore        Guy Hamilton
# 1977             The Spy Who Loved Me       Roger Moore       Lewis Gilbert
# ...

# %%
mask=bond["Budget"]>=40.0
bond.where(mask)
# Out:
#                          Film             Actor            Director  \
# Year
# 1962                      NaN               NaN                 NaN
# 1963                      NaN               NaN                 NaN
# 1964                      NaN               NaN                 NaN
# 1965              Thunderball  Sir Sean Connery       Terence Young
# 1967            Casino Royale       David Niven          Ken Hughes
# 1967      You Only Live Twice  Sir Sean Connery       Lewis Gilbert
# 1969                      NaN               NaN                 NaN
# 1971                      NaN               NaN                 NaN
# 1973                      NaN               NaN                 NaN
# 1974                      NaN               NaN                 NaN
# 1977     The Spy Who Loved Me       Roger Moore       Lewis Gilbert
# 1979                Moonraker       Roger Moore       Lewis Gilbert
# 1981       For Your Eyes Only       Roger Moore           John Glen
# ...

# %%
bond.columns=[column_name.replace(" ","_") for column_name in bond.columns]

# %%
bond
# Out:
#                                  Film             Actor            Director  \
# Year
# 1962                           Dr. No  Sir Sean Connery       Terence Young
# 1963            From Russia with Love  Sir Sean Connery       Terence Young
# 1964                       Goldfinger  Sir Sean Connery        Guy Hamilton
# 1965                      Thunderball  Sir Sean Connery       Terence Young
# 1967                    Casino Royale       David Niven          Ken Hughes
# 1967              You Only Live Twice  Sir Sean Connery       Lewis Gilbert
# 1969  On Her Majesty's Secret Service    George Lazenby       Peter R. Hunt
# 1971             Diamonds Are Forever  Sir Sean Connery        Guy Hamilton
# 1973                 Live and Let Die       Roger Moore        Guy Hamilton
# 1974      The Man with the Golden Gun       Roger Moore        Guy Hamilton
# 1977             The Spy Who Loved Me       Roger Moore       Lewis Gilbert
# ...

# %%
triangle = [[1, 0, 0, 2], 
          [0, 5, 0, 1], 
          [0, 0, 3, 5]]
del triangle[1]
triangle=[row[:0] + row[0+1:] for row in triangle]
triangle=[row[:1] + row[1+1:] for row in triangle]
triangle
# Out:
# [[0, 2], [0, 5]]
